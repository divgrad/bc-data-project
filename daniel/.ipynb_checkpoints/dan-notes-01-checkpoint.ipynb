# %% [markdown]
# ## What does the data mean?

# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %% [markdown]
# Number of data points is 57,891,462. We need a way to reduce this for visualization / initial analysis.

# %%
# !wc -l /home/slothrop/smart-shores/data/Hwy\ 16\ at\ Davis\ Bay.txt
# Out:
# 57891462 /home/slothrop/smart-shores/data/Hwy 16 at Davis Bay.txt

# %% [markdown]
# Here are the top five lines of data. What does each columb represent?

# %%
# !head -n 5 /home/slothrop/smart-shores/data/Hwy\ 16\ at\ Davis\ Bay.txt
# Out:
# -123.729482 49.443884 -2.659747 90 71 50 -0.226857 0.192817 0.954650
# -123.729480 49.443888 -2.665898 63 46 26 -0.098237 -0.097561 0.990369
# -123.729487 49.443889 -2.722657 57 41 28 -0.385735 0.439581 0.811158
# -123.729490 49.443891 -2.715879 53 35 21 0.026436 -0.240092 0.970390
# -123.729484 49.443891 -2.699979 61 44 26 -0.031485 -0.089581 0.995482

# %% [markdown]
# For <b>Vancouver</b> we have Latitude = 49.25, Longtitude = -123.12. So the first column of data is longtitude, the second is latitude. It will be better to get a sense of this in terms of standard units [m] or [cm].

# %% [markdown]
# Extract a random sample (size after -n ) of the original data.

# %%
# !shuf -n 20000 /home/slothrop/smart-shores/data/Hwy\ 16\ at\ Davis\ Bay.txt > /home/slothrop/smart-shores/sample.txt

# %%
data = pd.read_csv('sample.txt',sep=" ", header=None)

# %%
column_names = ['lon', 'lat', 'z', 'r', 'g', 'b', 'j', 'k', 'l']
data.columns = column_names

# %%
data.shape
# Out:
# (20000, 9)

# %%
data.head()
# Out:
#           lon        lat          z    r    g   b         j         k  \
# 0 -123.732079  49.451658  19.866621  132  120  15  0.526032 -0.518690
# 1 -123.722699  49.439979  20.089634   92   98  16 -0.678925 -0.432425
# 2 -123.731505  49.450149  -1.441351  140  118  62 -0.139623  0.015492
# 3 -123.726837  49.438029  -1.782528  139  119  31  0.013696  0.017363
# 4 -123.730582  49.449975  10.281753   80   36  33  0.186497  0.889791
#
#           l
# 0  0.673981
# 1  0.593355
# 2  0.990083
# 3  0.999755
# 4  0.416522

# %%
data.describe().transpose()
# Out:
#      count        mean        std         min         25%         50%  \
# lon  20000 -123.727398   0.002644 -123.733832 -123.729177 -123.727667
# lat  20000   49.442981   0.004345   49.436327   49.439555   49.441398
# z    20000    3.463856   6.828267   -7.650711   -1.176712    1.201272
# r    20000  144.827550  58.740988    5.000000  103.000000  155.000000
# g    20000  121.843150  51.361853    5.000000   86.000000  126.000000
# b    20000   70.388500  48.259008    0.000000   28.000000   62.000000
# j    20000   -0.078924   0.322454   -0.999953   -0.166193   -0.052736
# k    20000   -0.046208   0.320335   -0.999933   -0.124019   -0.023183
# l    20000    0.827680   0.316238   -0.891600    0.829621    0.983480
#
#             75%         max
# lon -123.725285 -123.721684
# lat   49.446478   49.452771
# z      4.605196   39.681795
# r    192.000000  255.000000
# g    161.000000  255.000000
# b    108.000000  255.000000
# j      0.038166    0.999011
# k      0.055561    0.998519
# l      0.996253    0.999996

# %% [markdown]
# Based on the above data and converting second changes let's figure out what kind of area we are dealing with.

# %%
scaler = StandardScaler()

lon_ = scaler.fit_transform(data['lon'].values.reshape(-1,1)).ravel()
lat_ = data['lat'].values
lat_ = (lat_ - lat_.mean()) / scaler.scale_
z_ = data['z'].values
z_ = (z_ - z_.mean()) / scaler.scale_

lon_lat_z_ = np.vstack((lon_, lat_, z_)).T

rgb = data.loc[:, ['r','g','b']].values
rgb_01 = rgb/255

plt.figure(figsize=(10, 10))
plt.scatter(lon_lat_z_[:, 0], lon_lat_z_[:, 1], s=3, c=rgb_01,lw=0);
plt.axis('equal');
